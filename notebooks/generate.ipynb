# %%
from mimesis import Person
from mimesis.locales import Locale
from mimesis.enums import Gender
from mimesis import Address
from mimesis.builtins import RussiaSpecProvider
import pandas as pd
import random

# %%
person = Person(Locale.RU)
person_address = Address(Locale.RU)
person_ru = RussiaSpecProvider()

def gen_data(count):
    struct_raw = {
        'first_name': [],
        'last_name': [],
        'patronymic': [],
        'age': [],
        'email': [],
        'first_name': [],
        'phone_number': [],
        'username': [],
        'occupation': [],
        'location': [],
    }

    for i in range(count):
        gender = random.choice([Gender.MALE, Gender.FEMALE])
        struct_raw['first_name'].append(person.first_name(gender))
        struct_raw['last_name'].append(person.last_name(gender))
        struct_raw['patronymic'].append(person_ru.patronymic(gender))
        struct_raw['age'].append(person.age())
        struct_raw['email'].append(person.email())
        struct_raw['phone_number'].append(person.phone_number())
        struct_raw['username'].append(person.username())
        struct_raw['occupation'].append(person.occupation())
        struct_raw['location'].append(person_address.city())
    
    return pd.DataFrame(struct_raw)

raw_data = gen_data(100)

raw_data
# Out:
#     first_name   last_name     patronymic  age                        email  \
# 0        Лукий  Северьянов    Ярославович   18     enlargement1992@duck.com
# 1         Юрий     Панкеев      Ерофеевич   17    apartment1968@example.org
# 2   Иннокентий   Шалыганов  Владиславович   36         compete1985@live.com
# 3        Юстин   Кнабенгоф       Ефимович   16        diane2034@outlook.com
# 4     Корнилий        Янов    Иларионович   18       answered1842@gmail.com
# ..         ...         ...            ...  ...                          ...
# 95      Вавила      Лыткин    Гертрудович   37    engineers2042@example.com
# 96      Стелла    Каганова      Иосифовна   58    duties1872@protonmail.com
# 97       Денис     Солнцев     Трифонович   21    shortcuts1853@example.com
# 98     Добрыня    Памфилов    Григорьевич   17       nurses1814@example.com
# 99     Беатрис     Сиднина     Зиновьевна   23  comparisons2077@example.com
#
#           phone_number       username               occupation       location
# 0   +7-(909)-550-45-90  inserted_2025                    Химик          Любим
# 1   +7-(927)-964-22-76   lexmark_1832  Администратор гостиницы   Железноводск
# 2   +7-(909)-181-59-53      rope_1895             Эндокринолог          Жуков
# 3   +7-(955)-738-94-66    united_2061                Космонавт     Партизанск
# 4   +7-(909)-966-43-53      game_2000             Эндокринолог          Янаул
# ..                 ...            ...                      ...            ...
# 95  +7-(923)-476-27-86  weekends_1919                 Технолог         Жиздра
# 96  +7-(925)-645-10-22   camping_2000                Космонавт  Новомичуринск
# 97  +7-(925)-141-60-60     worth_1922              Автомеханик      Шимановск
# 98  +7-(965)-669-56-46   loading_2085            Авиадиспетчер        Алзамай
# 99  +7-(968)-701-87-61     omega_1915                Иммунолог      Звенигово
#
# [100 rows x 9 columns]

# %%
raw_data.to_csv('gen_data.csv')
