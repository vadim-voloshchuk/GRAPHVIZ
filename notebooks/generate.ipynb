# %%
from mimesis import Person
from mimesis.locales import Locale
from mimesis.enums import Gender
from mimesis import Address
from mimesis.builtins import RussiaSpecProvider
import pandas as pd
import random

# %%
person = Person(Locale.RU)
person_address = Address(Locale.RU)
person_ru = RussiaSpecProvider()

def gen_data(count):
    struct_raw = {
        'first_name': [],
        'last_name': [],
        'patronymic': [],
        'age': [],
        'email': [],
        'first_name': [],
        'phone_number': [],
        'username': [],
        'occupation': [],
        'location': [],
        'language': [],
        'university': [],
        'work_experience': [],
    }

    for i in range(count):
        gender = random.choice([Gender.MALE, Gender.FEMALE])
        struct_raw['first_name'].append(person.first_name(gender))
        struct_raw['last_name'].append(person.last_name(gender))
        struct_raw['patronymic'].append(person_ru.patronymic(gender))
        struct_raw['age'].append(person.age())
        struct_raw['email'].append(person.email())
        struct_raw['phone_number'].append(person.phone_number())
        struct_raw['username'].append(person.username())
        struct_raw['occupation'].append(person.occupation())
        struct_raw['location'].append(person_address.city())
        struct_raw['language'].append(person.language())
        struct_raw['university'].append(person.university())
        struct_raw['work_experience'].append(person.work_experience())
    
    return pd.DataFrame(struct_raw)

raw_data = gen_data(100)

raw_data
# Out:
#    first_name    last_name    patronymic  age                      email  \
# 0      Матвей  Поляновский         Ильич   55    country1890@example.com
# 1      Самуил       Кантор    Харламович   21       renew1837@yandex.com
# 2        Ефим     Бруштейн    Васильевич   16      playback2045@duck.com
# 3       Шерил     Ремизова   Ярославовна   60         ugly1884@gmail.com
# 4     Сильвия      Куркова    Исидоровна   48     victor1818@outlook.com
# ..        ...          ...           ...  ...                        ...
# 95     Тамара      Зайцева    Харламовна   43      south2036@example.com
# 96   Иллирика     Буторина   Владленовна   59     rochester2092@live.com
# 97      Гаянэ      Осокина  Харлампьевна   56         given2024@duck.com
# 98    Георгий  Кругосветов     Сидорович   37        cents1872@gmail.com
# 99      Илина      Донцова     Тимуровна   38  commissions1897@gmail.com
#
#           phone_number        username           occupation       location  \
# 0   +7-(909)-003-22-47       kyle_1833             Охранник        Бологое
# 1   +7-(967)-595-90-61      rocky_1879            Металлург  Солнечногорск
# 2   +7-(909)-589-27-86   recently_2014       Мультипликатор        Салават
# 3   +7-(968)-379-48-85     figure_1923   Врач скорой помощи           Холм
# 4   +7-(909)-735-92-95       east_1918            Фармацевт         Элиста
# ..                 ...             ...                  ...            ...
# 95  +7-(909)-812-54-31    stomach_2088  Инженер-конструктор         Самара
# 96  +7-(975)-344-95-75      rolls_1981               Пастух          Сурск
# 97  +7-(968)-616-49-88     monroe_1939               Горняк          Лиски
# 98  +7-(925)-921-45-42   reseller_1838      Web-программист        Нолинск
# 99  +7-(929)-231-91-77  empirical_1967   Постановщик трюков    Новоалтайск
#
#          language                                         university  \
# 0       Читтагонг                              САУ им. С.П. Королева
# 1       Амхарский                    Московский авиационный институт
# 2   Малагасийский                                               МФТИ
# 3        Турецкий  Санкт-Петербургский государственный политехнич...
# 4   Португальский         Филиал Академии Генеральной прокуратуры РФ
# ..            ...                                                ...
# 95     Непальский  Государственный технологический университет им...
# 96       Харьянви                                 МГУ им. Ломоносова
# 97  Малагасийский       Университет аэрокосмического приборостроения
# 98      Бходжпури    Санкт-Петербургский политехнический университет
# 99     Английский  Санкт-Петербургский государственный политехнич...
#
#     work_experience
# 0                33
# 1                 0
# 2                 0
# 3                38
# 4                26
# ..              ...
# 95               21
# 96               37
# 97               34
# 98               15
# 99               16
#
# [100 rows x 12 columns]

# %%
raw_data.to_csv('gen_data.csv')
